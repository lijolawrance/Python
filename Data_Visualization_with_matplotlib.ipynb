# %% [markdown]
# <a href="https://colab.research.google.com/github/lijolawrance/Python/blob/main/Data_Visualization_with_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. BASIC LINE PLOT

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
stock_df = pd.read_csv('/content/sample_data/stocks.csv')
stock_df
# Out:
#             Date        AAPL          BA  ...         TSLA         GOOG        sp500
# 0     2012-01-12   60.198570   75.510002  ...    28.250000   313.644379  1295.500000
# 1     2012-01-13   59.972858   74.599998  ...    22.790001   311.328064  1289.089966
# 2     2012-01-17   60.671429   75.239998  ...    26.600000   313.116364  1293.670044
# 3     2012-01-18   61.301430   75.059998  ...    26.809999   315.273285  1308.040039
# 4     2012-01-19   61.107143   75.559998  ...    26.760000   318.590851  1314.500000
# ...          ...         ...         ...  ...          ...          ...          ...
# 2154  2020-08-05  440.250000  174.279999  ...  1485.020020  1473.609985  3327.770020
# 2155  2020-08-06  455.609985  172.199997  ...  1489.579956  1500.099976  3349.159912
# 2156  2020-08-07  444.450012  170.020004  ...  1452.709961  1494.489990  3351.280029
# 2157  2020-08-10  450.910004  179.410004  ...  1418.569946  1496.099976  3360.469971
# 2158  2020-08-11  437.500000  180.130005  ...  1374.390015  1480.319946  3333.689941
#
# [2159 rows x 10 columns]

# %%
stock_df.plot(x='Date', y='AAPL', label='Apple stock Prices', linewidth=3)
plt.ylabel('Price')
plt.legend(loc='upper right')
plt.title("dt")
# Out:
# Text(0.5, 1.0, 'dt')

# %%
# Read the stock prices data using pandas

# %% [markdown]
# **MINI CHALLLENGE #1:**
# - **Plot similar kind of graph for the S&P500**
# - **Change the line color to red**

# %%
stock_df.plot(x='Date', y='sp500', label='sp500 stock Prices',color='g', linewidth=3)
plt.ylabel('Price')
#plt.legend(loc='upper right')
plt.title("dt")
# Out:
# Text(0.5, 1.0, 'dt')

# %% [markdown]
# # 2. SCATTERPLOT

# %%
# Read daily return data using pandas
returns_df = pd.read_csv('/content/sample_data/daily_returns.csv')
returns_df
# Out:
#           AAPL     sp500      GOOG
# 0     0.000000  0.000000  0.000000
# 1    -0.374946 -0.494792 -0.738516
# 2     1.164812  0.355295  0.574410
# 3     1.038382  1.110793  0.688856
# 4    -0.316937  0.493866  1.052283
# ...        ...       ...       ...
# 2154  0.362467  0.642974  0.589774
# 2155  3.488923  0.642770  1.797626
# 2156 -2.449458  0.063303 -0.373974
# 2157  1.453480  0.274222  0.107728
# 2158 -2.973987 -0.796913 -1.054744
#
# [2159 rows x 3 columns]

# %%
X=returns_df['AAPL']
Y=returns_df['sp500']
plt.scatter(X,Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3557e9692f82> in <module>()
#       1 X=returns_df['AAPL']
#       2 Y=returns_df['sp500']
# ----> 3 plt.scatter(X,Y , c=r)
#
# NameError: name 'r' is not defined

# %% [markdown]
# **MINI CHALLLENGE #2:**
# - **Plot similar kind of graph for GOOG and sp500**

# %%
X=returns_df['GOOG']
Y=returns_df['sp500']
plt.scatter(X,Y)

# %% [markdown]
# # 3. PIE CHART

# %%
values=[20,55,5,17,4]
colors=['g','r','y','b','m']
labels =['AAPL','GOOG','T','TSLA','AMZN']
plt.figure(figsize=(7,7))
plt.pie(values,colors=colors,labels=labels, explode=[0,0.4,0,0.1,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5b5b7df450>,
#   <matplotlib.patches.Wedge at 0x7f5b5b7df8d0>,
#   <matplotlib.patches.Wedge at 0x7f5b5b7df890>,
#   <matplotlib.patches.Wedge at 0x7f5b5b7e9490>,
#   <matplotlib.patches.Wedge at 0x7f5b5b7e9dd0>],
#  [Text(0.8939237040226363, 0.6410151413082613, 'AAPL'),
#   Text(-1.4739528878136021, 0.2783215487631934, 'GOOG'),
#   Text(0.11951748318547765, -1.0934878011267475, 'T'),
#   Text(0.8551008338506573, -0.8419041299031089, 'TSLA'),
#   Text(1.0914968694541507, -0.13650854907949475, 'AMZN')])

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Plot the pie chart for the same stocks assuming equal allocation**
# - **Explode Amazon and Google slices**

# %%
values=[20,20,20,20,20]
colors=['g','r','y','b','m']
labels =['AAPL','GOOG','T','TSLA','AMZN']
plt.figure(figsize=(7,7))
plt.pie(values,colors=colors,labels=labels, explode=[0.2,0.2,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5b5b791910>,
#   <matplotlib.patches.Wedge at 0x7f5b5b791d90>,
#   <matplotlib.patches.Wedge at 0x7f5b5b71c390>,
#   <matplotlib.patches.Wedge at 0x7f5b5b71c450>,
#   <matplotlib.patches.Wedge at 0x7f5b5b7282d0>],
#  [Text(1.0517220855332163, 0.764120837827148, 'AAPL'),
#   Text(-0.4017221274147229, 1.2363734599001182, 'GOOG'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, 'T'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'TSLA'),
#   Text(0.8899187482945414, -0.6465637025335375, 'AMZN')])

# %% [markdown]
# # 4. HISTOGRAMS

# %%
# A histogram represents data using bars of various heights. 
# Each bar groups numbers into specific ranges. 
# Taller bars show that more data falls within that specific range.
mean=returns_df['AAPL'].mean()
sigma=returns_df['AAPL'].std()

# %%
num_bins=40
plt.figure(figsize=(7,5))
plt.hist(returns_df['AAPL'],num_bins);
plt.grid()
plt.title('Histogram mean='+str(mean) +', Sigma=' + str(sigma))
# Out:
# Text(0.5, 1.0, 'Histogram mean=0.1076954943715465, Sigma1.7757676749017137')

# %% [markdown]
# **MINI CHALLLENGE #4:**
# - **Plot the histogram for GOOG returns using 30 bins**

# %%
mean,sigma=returns_df['GOOG'].mean(),returns_df['GOOG'].std()
num_bins=30
plt.figure(figsize=(7,5))
plt.hist(returns_df['GOOG'],num_bins);
plt.grid()
plt.title('Histogram mean='+str(mean) +', Sigma=' + str(sigma))
# Out:
# Text(0.5, 1.0, 'Histogram mean=0.08439182335261494, Sigma=1.5855578722362975')

# %% [markdown]
# # 5. MULTIPLE PLOTS

# %%
stock_df.plot(x='Date', y=['AAPL','GOOG','sp500'],  linewidth=3)
plt.ylabel('Price')
plt.legend(loc='upper right')
plt.title("dt")
plt.grid()

# %% [markdown]
# **MINI CHALLLENGE #5:**
# - **Plot a similar graph containing prices of AAPL, sp500 and GOOG**
# - **Add legend indicating S&P500, AAPL and GOOG**
# - **Place the legend in the "upper center" location**

# %%
stock_df.plot(x='Date', y=['AAPL','GOOG','sp500'],  linewidth=3)
plt.ylabel('Price')
plt.legend(loc='upper center')
plt.title("dt")
plt.grid()

# %% [markdown]
# # 6. SUBPLOTS

# %%
plt.figure(figsize = (8,5))
plt.subplot(1,2,1)
plt.plot(stock_df['AAPL'],'r--')
plt.grid()
plt.subplot(1,2,2)
plt.plot(stock_df['sp500'],'b--')
plt.grid()

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# **MINI CHALLLENGE #6:**
# - **Create subplots like above for GOOG, AAPL and sp500**

# %%
plt.figure(figsize = (8,8))
plt.subplot(3,1,1)
plt.plot(stock_df['AAPL'],'r--')
plt.grid()
plt.subplot(3,1,2)
plt.plot(stock_df['GOOG'],'g--')
plt.grid()
plt.subplot(3,1,3)
plt.plot(stock_df['sp500'],'b--')
plt.grid()

# %% [markdown]
# # 7. 3D PLOTS

# %%
# Toolkits are collections of application-specific functions that extend Matplotlib.
# mpl_toolkits.mplot3d provides tools for basic 3D plotting.
# https://matplotlib.org/mpl_toolkits/index.html

from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize = (6,6))
ax=fig.add_subplot(111,projection = '3d')
ax.scatter(returns_df['sp500'],returns_df['GOOG'], returns_df['AAPL'], c='g',marker='1')

# %% [markdown]
# **MINI CHALLLENGE #7:**
# - **Create a 3D plot with daily return values of sp500, GOOG and AAPL**

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize = (6,6))
ax=fig.add_subplot(111,projection = '3d')
ax.scatter(returns_df['sp500'],returns_df['GOOG'], returns_df['AAPL'], c='g',marker='o')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-ace4cfc8a9ac> in <module>()
#       2 fig=plt.figure(figsize = (6,6))
#       3 ax=fig.add_subplot(111,projection = '3d')
# ----> 4 ax.bar3d(returns_df['sp500'],returns_df['GOOG'], returns_df['AAPL'], c='g',marker='o')
#
# TypeError: bar3d() missing 3 required positional arguments: 'dx', 'dy', and 'dz'

# %% [markdown]
# # 8. BOXPLOTS

# %%
# numpy.random.normal() takes three arguments: mean, standard deviation of the normal distribution, and number of values desired.
# Great resource: https://stackoverflow.com/questions/17725927/boxplots-in-matplotlib-markers-and-outliers
np.random.seed(20)
data_1=np.random.normal(200,20,2000)
data_2=np.random.normal(60,30,2000)
data_3=np.random.normal(70,20,2000)
data_4=np.random.normal(40,5,2000)

data = [data_1, data_2, data_3, data_4]
fig=plt.figure(figsize=(10,7))
ax=fig.add_subplot(111)
bp=ax.boxplot(data)

# %% [markdown]
# **MINI CHALLENGE #8:**
# - **Plot the box plot for  a new dataset data_5 that is normally distributed with an average of 800 and standard deviation = 100**

# %%
data_5=np.random.normal(800,100,2000)
data = [data_1, data_2, data_3, data_4,data_5]
fig=plt.figure(figsize=(10,7))
ax=fig.add_subplot(111)
bp=ax.boxplot(data)

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # MINI CHALLENGES SOLUTIONS

# %% [markdown]
# **MINI CHALLLENGE #1 SOLUTIONS:**
# - **Plot similar kind of graph for sp500**
# - **Change the color line to red**

# %%
stock_df.plot(x = 'Date', y = 'sp500', label = 'P500', color = 'r');
plt.ylabel('Price')
plt.title('My first plotting exercise!')
plt.legend(loc="upper left")
plt.grid()

# %% [markdown]
# **MINI CHALLLENGE #2 SOLUTIONS:**
# - **Plot similar kind of graph for GOOG and sp500**

# %%
X = daily_return_df['GOOG']
Y = daily_return_df['sp500']

plt.scatter(X, Y);

# %% [markdown]
# **MINI CHALLLENGE #3 SOLUTIONS:**
# - **Plot the pie chart for the same stocks assuming equal allocation**
# - **Explode Amazon and Google slices**

# %%
values = [20, 20, 20, 20, 20]
colors = ['g', 'r', 'y', 'b', 'm']
explode = [0, 0.2, 0, 0, 0.2]
labels = ['AAPL', 'GOOG', 'T', 'TSLA  ', 'AMZN']
plt.pie(values, colors = colors, labels = labels, explode = explode)
plt.title('STOCK PORTFOLIO')
plt.show()

# %% [markdown]
# **MINI CHALLLENGE #4 SOLUTIONS:**
# - **Plot the histogram for GOOG returns with 30 bins**

# %%
num_bins = 30
plt.hist(daily_return_df['GOOG'], num_bins, facecolor = 'blue');
plt.grid()

# %% [markdown]
# **MINI CHALLLENGE #5 SOLUTIONS:**
# - **Plot a similar graph containing prices of AAPL, sp500 and GOOG**
# - **Add legend indicating S&P500, AAPL and GOOG**
# - **Place the legend in the "upper center" location**

# %%
stock_df.plot(x = 'Date', y = ['AAPL', 'sp500', 'GOOG'], linewidth = 3)
plt.ylabel('Price')
plt.title('Stock Prices')
plt.legend(loc="upper center")
plt.grid()

# %% [markdown]
# **MINI CHALLLENGE #6 SOLUTIONS:**
# - **Create subplots like above for GOOG, AAPL and sp500**

# %%
plt.figure(figsize = (7,7))
plt.subplot(3, 1, 1)
plt.plot(stock_df.index, stock_df['AAPL'], 'r--');
plt.grid()
plt.legend(['APPLE price'])

plt.subplot(3, 1, 2)
plt.plot(stock_df.index, stock_df['sp500'], 'b.');
plt.grid()
plt.legend(['S&P500 price'])


plt.subplot(3, 1, 3)
plt.plot(stock_df.index, stock_df['GOOG'], 'y--');
plt.grid()
plt.legend(['GOOGLE price'])

# %% [markdown]
# **MINI CHALLLENGE #7 SOLUTIONS:**
# - **Create a 3D plot with daily return values of sp500, GOOG and AAPL**

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection = '3d')

x = daily_return_df['AAPL'].tolist()
y = daily_return_df['sp500'].tolist()
z = daily_return_df['GOOG'].tolist()

ax.scatter(x, y, z, c = 'r', marker = 'o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# %% [markdown]
# **MINI CHALLENGE #8 SOLUTIONS:**
# - **Plot the box plot for  a new dataset that is normally distributed with an average of 800 and standard deviation = 100**

# %%
np.random.seed(20)

data_1 = np.random.normal(200, 20, 2000)
data_2 = np.random.normal(60, 30, 2000)
data_3 = np.random.normal(70, 20, 2000)
data_4 = np.random.normal(40, 5, 2000)
data_5 = np.random.normal(800, 100, 2000)


data_all = [data_1, data_2, data_3, data_4, data_5]

fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(111)
bp = ax.boxplot(data_all)
